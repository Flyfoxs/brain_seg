# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="2"
from file_cache import *
from fastai.vision import *
from fastai.callbacks.hooks import *

import torch
from torch import nn
from torchviz import make_dot, make_dot_from_trace
from brain.module_unet import *

# %%
model = dynamic_unet( n_classes=5, img_size = (224,224))
#model(torch.rand(8,3,244,244).cuda())
from torchsummary import summary
summary(model.cuda(), (3,244,244))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 122, 122]           9,408
#        BatchNorm2d-2         [-1, 64, 122, 122]             128
#               ReLU-3         [-1, 64, 122, 122]               0
#          MaxPool2d-4           [-1, 64, 61, 61]               0
#             Conv2d-5           [-1, 64, 61, 61]           4,096
#        BatchNorm2d-6           [-1, 64, 61, 61]             128
#               ReLU-7           [-1, 64, 61, 61]               0
#             Conv2d-8           [-1, 64, 61, 61]          36,864
#        BatchNorm2d-9           [-1, 64, 61, 61]             128
#              ReLU-10           [-1, 64, 61, 61]               0
#            Conv2d-11          [-1, 256, 61, 61]          16,384
#       BatchNorm2d-12          [-1, 256, 61, 61]             512
#            Conv2d-13          [-1, 256, 61, 61]          16,384
# ...

# %%
#!sudo apt-get install graphviz -y

# %%
model = unet_normal( n_classes=5, img_size = (224,224))
make_dot(model(torch.rand(8,3,244,244)), params=dict(model.named_parameters()))
pass

# %%
from torchsummary import summary
summary(model.cuda(), (3,244,244))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 244, 244]           1,792
#               ReLU-2         [-1, 64, 244, 244]               0
#        BatchNorm2d-3         [-1, 64, 244, 244]             128
#             Conv2d-4         [-1, 64, 244, 244]          36,928
#               ReLU-5         [-1, 64, 244, 244]               0
#        BatchNorm2d-6         [-1, 64, 244, 244]             128
#      UNetConvBlock-7         [-1, 64, 244, 244]               0
#             Conv2d-8        [-1, 128, 122, 122]          73,856
#               ReLU-9        [-1, 128, 122, 122]               0
#       BatchNorm2d-10        [-1, 128, 122, 122]             256
#            Conv2d-11        [-1, 128, 122, 122]         147,584
#              ReLU-12        [-1, 128, 122, 122]               0
#       BatchNorm2d-13        [-1, 128, 122, 122]             256
# ...
